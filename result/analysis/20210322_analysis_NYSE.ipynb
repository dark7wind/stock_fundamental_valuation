# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yaml
import MySQLdb as mdb
# from definitions import DATABASE_CONFIG_DIR, INCOME_STATEMENT_DIR

# %% [markdown]
# ## load stock info

# %%
with open('../../database/database_config/database.ymal') as f:
    db_config = yaml.load(f, Loader=yaml.FullLoader)
db = mdb.connect(host=db_config['db_host'], user=db_config['db_user'], passwd=db_config['db_pass'],
                 db=db_config['db_name'], use_unicode=True, charset="utf8")
# select stockId and ticker from table stock_info
table_name = 'stock_info'
column_list = ['stockId', 'ticker', 'IndustryGroup']
columns = ','.join(column_list)
req = """SELECT %s FROM %s WHERE exchange='NYSE' """ % (columns, table_name)
get_stock_info_cursor = db.cursor()
get_stock_info_cursor.execute(req)
stock_info = get_stock_info_cursor.fetchall()
get_stock_info_cursor.close()

#create dataframe
df_stock_info = pd.DataFrame(stock_info, columns=column_list)

# %%
df_stock_info.head(5)
# Out:
#    stockId ticker             IndustryGroup
# 0        5    ELS                  R.E.I.T.
# 1       11    PNR                 Machinery
# 2       28    WSM  Retail (Building Supply)
# 3       34    ACM  Engineering/Construction
# 4       37   ALLE        Building Materials

# %% [markdown]
# ## load the file

# %%
file = '../20210321_valuation_result_sp500.csv'
df_valuation = pd.read_csv(file)

# %%
df_valuation.head(5)
# Out:
#   ticker  current_price  estimated_value  price_to_value
# 0    PNR          61.02        35.352727        1.726034
# 1   ALLE         119.92        80.469651        1.490251
# 2    ITW         218.69       154.809823        1.412636
# 3   AMAT         114.86       104.682096        1.097227
# 4    NWL          26.09        14.159187        1.842620

# %%
df_valuation.describe()
# Out:
#        current_price  estimated_value  price_to_value
# count     489.000000       487.000000      487.000000
# mean      171.612035     -1717.212123        1.043718
# std       297.240590     26572.823283       18.968509
# min        11.020000   -460520.985894     -191.593746
# 25%        59.730000        20.055851        0.734154
# 50%       106.770000        65.095890        1.326223
# 75%       188.330000       126.368253        2.126902
# max      4434.990000     16134.444236      174.252492

# %% [markdown]
# ## merge two dataframes

# %%
df = pd.merge(df_valuation, df_stock_info, left_on='ticker', right_on='ticker', how='left')

# %%
## filter out finanace sector 
df = df.loc[(df['IndustryGroup']!='Financial Svcs. (Non-bank & Insurance)')
                 & (df['IndustryGroup']!='Banks (Regional)') 
                 & (df['IndustryGroup']!='Bank (Money Center)') 
                 & (df['IndustryGroup']!='Brokerage & Investment Banking') 
                 & (df['IndustryGroup']!='Investments & Asset Management') 
                 & (df['IndustryGroup']!='Insurance (Life)')
                 & (df['IndustryGroup']!='Insurance (Prop/Cas.)')
                 & (df['IndustryGroup']!='Insurance (General)')]

# %% [markdown]
# ## EDA

# %%
df.hist(column="price_to_value")
# Out:
# array([[<AxesSubplot:title={'center':'price_to_value'}>]], dtype=object)

# %% [markdown]
# ### calculate the range

# %%
def cut_to(x):
    if x<0:
        return 'less than 0'
    elif x<1:
        return '0-1'
    else:
        return 'larger than 1'

df['valuation_range'] = df['price_to_value'].map(cut_to)

# %%
df
# Out:
#     ticker  current_price  estimated_value  price_to_value  stockId  \
# 0      PNR          61.02        35.352727        1.726034     11.0
# 1     ALLE         119.92        80.469651        1.490251     37.0
# 2      ITW         218.69       154.809823        1.412636     45.0
# 3     AMAT         114.86       104.682096        1.097227      NaN
# 4      NWL          26.09        14.159187        1.842620      NaN
# ..     ...            ...              ...             ...      ...
# 500    UAL          60.77     -1594.061325       -0.038123      NaN
# 501    CDW         158.03       104.903001        1.506439      NaN
# 502     MU          90.51       186.525600        0.485242      NaN
# 503   DLTR         108.12       117.833124        0.917569      NaN
# 504   INTC          63.76        60.872307        1.047439      NaN
#
#           IndustryGroup valuation_range
# 0             Machinery   larger than 1
# 1    Building Materials   larger than 1
# 2             Machinery   larger than 1
# 3                   NaN   larger than 1
# 4                   NaN   larger than 1
# ..                  ...             ...
# 500                 NaN     less than 0
# 501                 NaN   larger than 1
# 502                 NaN             0-1
# 503                 NaN             0-1
# 504                 NaN   larger than 1
#
# [456 rows x 7 columns]

# %%
df['valuation_range'].value_counts()
# Out:
# larger than 1    314
# 0-1               77
# less than 0       65
# Name: valuation_range, dtype: int64

# %% [markdown]
# ## sort

# %%
df.sort_values(by=['price_to_value'])
# Out:
#     ticker  current_price  estimated_value  price_to_value  stockId  \
# 125   HOLX          72.03        -0.375952     -191.593746      NaN
# 5      MAA         141.52        -0.821716     -172.224911     54.0
# 346     DD          77.10        -0.461416     -167.094412   6448.0
# 89     REG          56.06        -0.422219     -132.774737      NaN
# 12     GPN         205.47        -7.807617      -26.316609    149.0
# ..     ...            ...              ...             ...      ...
# 342    BSX          38.17              NaN             NaN   6318.0
# 349    NWS            NaN              NaN             NaN      NaN
# 370   AMCR            NaN              NaN             NaN      NaN
# 401  GOOGL            NaN              NaN             NaN      NaN
# 456   CBOE            NaN              NaN             NaN      NaN
#
#             IndustryGroup valuation_range
# 125                   NaN     less than 0
# 5                R.E.I.T.     less than 0
# 346  Chemical (Specialty)     less than 0
# 89                    NaN     less than 0
# 12   Information Services     less than 0
# ..                    ...             ...
# 342   Healthcare Products   larger than 1
# 349                   NaN   larger than 1
# 370                   NaN   larger than 1
# 401                   NaN   larger than 1
# 456                   NaN   larger than 1
#
# [456 rows x 7 columns]

# %% [markdown]
# ### select the valuation between 0-1

# %%
df = df.loc[df['valuation_range'] == '0-1']
df = df.sort_values(by=['price_to_value'])

# %%
df.hist(column="price_to_value")
# Out:
# array([[<AxesSubplot:title={'center':'price_to_value'}>]], dtype=object)

# %%
df.head(10)
# Out:
#     ticker  current_price  estimated_value  price_to_value  stockId  \
# 138    HLT        124.390       928.581609        0.133957   2632.0
# 58    BKNG       2287.740     16134.444236        0.141792      NaN
# 14     MAR        152.280      1036.427525        0.146928      NaN
# 431     RL        121.750       338.938647        0.359210   8292.0
# 362    DHI         83.630       186.927851        0.447392   6698.0
# 275   FOXA         42.925        92.944763        0.461833      NaN
# 53     PHM         48.990       104.730680        0.467771   1120.0
# 502     MU         90.510       186.525600        0.485242      NaN
# 23      CI        243.260       492.525613        0.493903    344.0
# 427   SIVB        544.610      1075.098049        0.506568      NaN
#
#                    IndustryGroup valuation_range
# 138                 Hotel/Gaming             0-1
# 58                           NaN             0-1
# 14                           NaN             0-1
# 431                      Apparel             0-1
# 362                 Homebuilding             0-1
# 275                          NaN             0-1
# 53                  Homebuilding             0-1
# 502                          NaN             0-1
# 23   Healthcare Support Services             0-1
# 427                          NaN             0-1

# %%
df.loc[(df['price_to_value']>0.6) & (df['price_to_value']<0.8)]
# Out:
#     ticker  current_price  estimated_value  price_to_value  stockId  \
# 251    MCK         189.77       315.815470        0.600889   4654.0
# 479    DXC          28.03        46.492635        0.602891   9425.0
# 137     LB          60.54        98.899051        0.612139   2566.0
# 140    ABC         115.92       186.629958        0.621122   2669.0
# 35     HII         197.26       314.914734        0.626392    680.0
# 334    IPG          29.59        46.785842        0.632456   6158.0
# 237    HUM         409.82       646.948582        0.633466   4408.0
# 296   PCAR          95.06       148.932156        0.638277      NaN
# 485    LYB         106.77       165.582364        0.644815   9481.0
# 247    UHS         138.00       213.589540        0.646099   4630.0
# 133    TSN          76.75       117.560327        0.652856   2473.0
# 429   HBAN          15.98        24.343271        0.656444      NaN
# 97     HPQ          30.08        45.300287        0.664013   1784.0
# 450    OMC          76.43       113.933680        0.670829   8755.0
# 405     FB         290.11       423.728365        0.684660      NaN
# 377   ABBV         103.42       150.481622        0.687260   7038.0
# 13     PFG          60.39        87.507656        0.690111      NaN
# 91     BWA          49.02        69.696316        0.703337   1690.0
# 194    LEN          95.12       133.322712        0.713457   3614.0
# 359    NVR        4434.99      6203.691162        0.714895   6660.0
# 43      WU          24.45        33.486439        0.730146    805.0
# 178    HFC          36.29        49.162614        0.738163   3351.0
# 318   BIIB         267.07       357.559971        0.746924      NaN
# 368    PVH         105.78       141.168126        0.749319   6862.0
# 26     CNC          64.24        84.468000        0.760525    375.0
# 105    HCA         188.60       242.062448        0.779138   2015.0
# 146    EMN         111.80       143.195501        0.780751   2698.0
# 163     MO          50.55        63.642770        0.794277   3130.0
# 103   DISH          37.28        46.864781        0.795480      NaN
#
#                        IndustryGroup valuation_range
# 251      Healthcare Support Services             0-1
# 479                Computer Services             0-1
# 137           Retail (Special Lines)             0-1
# 140      Healthcare Support Services             0-1
# 35                 Aerospace/Defense             0-1
# 334                      Advertising             0-1
# 237      Healthcare Support Services             0-1
# 296                              NaN             0-1
# 485                 Chemical (Basic)             0-1
# 247  Hospitals/Healthcare Facilities             0-1
# 133                  Food Processing             0-1
# 429                              NaN             0-1
# 97             Computers/Peripherals             0-1
# 450                      Advertising             0-1
# 405                              NaN             0-1
# 377            Drugs (Biotechnology)             0-1
# 13                               NaN             0-1
# 91                        Auto Parts             0-1
# 194                     Homebuilding             0-1
# 359                     Homebuilding             0-1
# 43              Information Services             0-1
# 178             Oilfield Svcs/Equip.             0-1
# 318                              NaN             0-1
# 368                          Apparel             0-1
# 26       Healthcare Support Services             0-1
# 105  Hospitals/Healthcare Facilities             0-1
# 146           Chemical (Diversified)             0-1
# 163                          Tobacco             0-1
# 103                              NaN             0-1
